# %% [markdown]
# # Correlation Analysis Notebook
#
# This notebook calculates the correlation between selected fields in a CSV file and visualizes the correlation matrix.

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Load the CSV File

# %%
# Replace 'your_file.csv' with your CSV file path
file_path = 'datasets/student_preferences_dataset.csv'

# Load the dataset
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    Age  Gender  Grade Level             Major Socioeconomic Status  \
# 0   24    Male            4  Computer Science                  Low
# 1   21    Male            2  Computer Science                  Low
# 2   22  Female            3  Computer Science                 High
# 3   24    Male            4  Computer Science                 High
# 4   20  Female            2  Computer Science               Medium
#
#   Language Proficiency Learning Style Course Format Interaction Type  \
# 0         Intermediate         Visual     In-person      Discussions
# 1                Basic         Visual        Online         Lectures
# 2         Intermediate    Kinesthetic        Online         Lectures
# 3         Intermediate         Visual     In-person       Group Work
# 4         Intermediate    Kinesthetic        Hybrid      Discussions
#
#   Engagement Level  ...  Time Spent on Homework  \
# 0              Low  ...                       3
# 1         Moderate  ...                       6
# 2             High  ...                       6
# 3         Moderate  ...                       8
# 4         Moderate  ...                       8
#
#    Time Spent on Additional Learning  Study Environment  Technological Access  \
# 0                                  7               Home                  Good
# 1                                  3               Home                  Good
# 2                                  4               Home                  Good
# 3                                  6            Library               Average
# 4                                  6            Library                  Good
#
#   Grades Test Scores  Course Completion Rates  Learning Style Preference  \
# 0     76          88                       87                     Visual
# 1     99          76                       67                   Auditory
# 2     72          93                       84                   Auditory
# 3     73          98                       69                   Auditory
# 4     50          63                       73                Kinesthetic
#
#    Course Format Preference Preference Uncertainty
# 0                 In-person         Highly Certain
# 1                 In-person         Highly Certain
# 2                 In-person         Highly Certain
# 3                 In-person     Moderately Certain
# 4                    Online         Highly Certain
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Step 2: Select Fields for Correlation Analysis

# %%
# Specify the fields for correlation analysis
selected_fields = ['Previous Courses Taken', 'Satisfaction with Past Courses', 'Time Spent on Homework', 'Time Spent on Additional Learning', 
                   'Test Scores', 'Course Completion Rates', 'Grades']  # Update with your column names
subset_data = data[selected_fields]

# Display the selected data
subset_data.head()
# Out:
#    Previous Courses Taken  Satisfaction with Past Courses  \
# 0                       8                               5
# 1                       1                               4
# 2                       6                               3
# 3                       2                               1
# 4                       5                               3
#
#    Time Spent on Homework  Time Spent on Additional Learning  Test Scores  \
# 0                       3                                  7           88
# 1                       6                                  3           76
# 2                       6                                  4           93
# 3                       8                                  6           98
# 4                       8                                  6           63
#
#    Course Completion Rates  Grades
# 0                       87      76
# 1                       67      99
# 2                       84      72
# 3                       69      73
# 4                       73      50

# %% [markdown]
# ## Step 3: Compute the Correlation Matrix

# %%
# Compute the correlation matrix
correlation_matrix = subset_data.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                                    Previous Courses Taken  \
# Previous Courses Taken                           1.000000
# Satisfaction with Past Courses                   0.000182
# Time Spent on Homework                          -0.002054
# Time Spent on Additional Learning               -0.000012
# Test Scores                                     -0.003289
# Course Completion Rates                          0.002354
# Grades                                           0.002112
#
#                                    Satisfaction with Past Courses  \
# Previous Courses Taken                                   0.000182
# Satisfaction with Past Courses                           1.000000
# Time Spent on Homework                                   0.000153
# Time Spent on Additional Learning                        0.001937
# Test Scores                                             -0.000964
# Course Completion Rates                                  0.001840
# Grades                                                  -0.000548
#
#                                    Time Spent on Homework  \
# Previous Courses Taken                          -0.002054
# Satisfaction with Past Courses                   0.000153
# Time Spent on Homework                           1.000000
# Time Spent on Additional Learning               -0.003282
# Test Scores                                     -0.002258
# Course Completion Rates                          0.003075
# Grades                                           0.000218
#
#                                    Time Spent on Additional Learning  \
# Previous Courses Taken                                     -0.000012
# Satisfaction with Past Courses                              0.001937
# Time Spent on Homework                                     -0.003282
# Time Spent on Additional Learning                           1.000000
# Test Scores                                                 0.002629
# Course Completion Rates                                    -0.003702
# Grades                                                      0.002390
#
#                                    Test Scores  Course Completion Rates  \
# Previous Courses Taken               -0.003289                 0.002354
# Satisfaction with Past Courses       -0.000964                 0.001840
# Time Spent on Homework               -0.002258                 0.003075
# Time Spent on Additional Learning     0.002629                -0.003702
# Test Scores                           1.000000                -0.001405
# Course Completion Rates              -0.001405                 1.000000
# Grades                               -0.003496                -0.002303
#
#                                      Grades
# Previous Courses Taken             0.002112
# Satisfaction with Past Courses    -0.000548
# Time Spent on Homework             0.000218
# Time Spent on Additional Learning  0.002390
# Test Scores                       -0.003496
# Course Completion Rates           -0.002303
# Grades                             1.000000

# %% [markdown]
# ## Step 4: Visualize the Correlation Matrix

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
