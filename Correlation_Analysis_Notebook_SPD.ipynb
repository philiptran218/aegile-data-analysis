# %% [markdown]
# # Correlation Analysis Notebook
#
# This notebook calculates the correlation between selected fields in a CSV file and visualizes the correlation matrix.

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Load the CSV File

# %%
# Replace 'your_file.csv' with your CSV file path
file_path = 'datasets/Student_Performance_Data(SPD24).xlsx'

# Load the dataset
data = pd.read_excel(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    Student ID  Gender  Age  Grade Level  Attendance Rate  Study Hours  \
# 0           1    Male   15           12        80.487800     2.764496
# 1           2  Female   17           12        96.242678     4.534785
# 2           3    Male   14            9        84.649681     2.008148
# 3           4    Male   14           10        86.158599     3.698293
# 4           5    Male   15           10        88.487638     3.408604
#
#   Parental Education Level Parental Involvement Extracurricular Activities  \
# 0               Bachelor's                 High                        Yes
# 1               Bachelor's                 High                        Yes
# 2               Bachelor's               Medium                        Yes
# 3              High School                 High                         No
# 4                Associate                  Low                         No
#
#   Socioeconomic Status  ...  Bullying Incidents Special Education Services  \
# 0                 High  ...                   1                         No
# 1                  Low  ...                   3                        Yes
# 2                  Low  ...                   0                        Yes
# 3                  Low  ...                   3                        Yes
# 4               Middle  ...                   1                        Yes
#
#   Counseling Services Learning Disabilities Behavioral Issues  \
# 0                 Yes                   Yes               Yes
# 1                 Yes                    No               Yes
# 2                  No                   Yes                No
# 3                  No                    No               Yes
# 4                 Yes                    No                No
#
#   Attendance of Tutoring Sessions School Climate Parental Employment Status  \
# 0                              No       Negative                 Unemployed
# 1                              No       Negative                   Employed
# 2                              No        Neutral                   Employed
# 3                              No       Positive                   Employed
# 4                              No       Positive                   Employed
#
#   Household Size  Performance Score
# 0              3                Low
# 1              3             Medium
# 2              3               High
# 3              4             Medium
# 4              6                Low
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Step 2: Select Fields for Correlation Analysis

# %%
# Specify the fields for correlation analysis
selected_fields = ['Attendance Rate', 'Study Hours', 'Previous Academic Performance', 'Hours of Sleep', 'Homework Completion Rate', 'Reading Proficiency', 
                   'Math Proficiency', 'Science Proficiency', 'Language Proficiency']  # Update with your column names
subset_data = data[selected_fields]

# Display the selected data
subset_data.head()
# Out:
#    Attendance Rate  Study Hours  Previous Academic Performance  \
# 0        80.487800     2.764496                      66.661594
# 1        96.242678     4.534785                      79.129923
# 2        84.649681     2.008148                      98.070597
# 3        86.158599     3.698293                      74.937204
# 4        88.487638     3.408604                      67.129520
#
#    Hours of Sleep  Homework Completion Rate  Reading Proficiency  \
# 0        6.485613                 86.568323            99.570689
# 1        5.973091                 84.184009            85.818975
# 2        7.740244                 76.310262            84.520809
# 3        7.995529                 64.108944            97.496243
# 4        8.864511                 84.945985            94.444113
#
#    Math Proficiency  Science Proficiency  Language Proficiency
# 0         86.725129            60.785049             90.309659
# 1         66.528350            64.268164             97.812943
# 2         94.547802            86.117803             69.853971
# 3         62.906840            82.763513             96.601016
# 4         76.347470            84.983862             70.108607

# %% [markdown]
# ## Step 3: Compute the Correlation Matrix

# %%
# Compute the correlation matrix
correlation_matrix = subset_data.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                                Attendance Rate  Study Hours  \
# Attendance Rate                       1.000000     0.000009
# Study Hours                           0.000009     1.000000
# Previous Academic Performance         0.000057    -0.001462
# Hours of Sleep                       -0.003445    -0.000946
# Homework Completion Rate             -0.004093     0.000593
# Reading Proficiency                   0.004082     0.004037
# Math Proficiency                     -0.000796     0.001384
# Science Proficiency                   0.005684     0.000038
# Language Proficiency                  0.002358     0.002539
#
#                                Previous Academic Performance  Hours of Sleep  \
# Attendance Rate                                     0.000057       -0.003445
# Study Hours                                        -0.001462       -0.000946
# Previous Academic Performance                       1.000000       -0.000347
# Hours of Sleep                                     -0.000347        1.000000
# Homework Completion Rate                           -0.001137        0.002147
# Reading Proficiency                                -0.004297       -0.002128
# Math Proficiency                                    0.002210        0.005207
# Science Proficiency                                -0.004252       -0.010180
# Language Proficiency                                0.000868       -0.001196
#
#                                Homework Completion Rate  Reading Proficiency  \
# Attendance Rate                               -0.004093             0.004082
# Study Hours                                    0.000593             0.004037
# Previous Academic Performance                 -0.001137            -0.004297
# Hours of Sleep                                 0.002147            -0.002128
# Homework Completion Rate                       1.000000            -0.001025
# Reading Proficiency                           -0.001025             1.000000
# Math Proficiency                               0.003580            -0.002774
# Science Proficiency                           -0.001960            -0.000702
# Language Proficiency                          -0.000644            -0.001604
#
#                                Math Proficiency  Science Proficiency  \
# Attendance Rate                       -0.000796             0.005684
# Study Hours                            0.001384             0.000038
# Previous Academic Performance          0.002210            -0.004252
# Hours of Sleep                         0.005207            -0.010180
# Homework Completion Rate               0.003580            -0.001960
# Reading Proficiency                   -0.002774            -0.000702
# Math Proficiency                       1.000000             0.008139
# Science Proficiency                    0.008139             1.000000
# Language Proficiency                  -0.004025             0.005115
#
#                                Language Proficiency
# Attendance Rate                            0.002358
# Study Hours                                0.002539
# Previous Academic Performance              0.000868
# Hours of Sleep                            -0.001196
# Homework Completion Rate                  -0.000644
# Reading Proficiency                       -0.001604
# Math Proficiency                          -0.004025
# Science Proficiency                        0.005115
# Language Proficiency                       1.000000

# %% [markdown]
# ## Step 4: Visualize the Correlation Matrix

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
